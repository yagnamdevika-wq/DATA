# %% [markdown]
# <a href="https://colab.research.google.com/github/yagnamdevika-wq/DATA/blob/main/DS_%26_ML_DAY3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "Student_ID": [1,2,3,4,5],

    "Name": ["Anu","Ravi","Sita","Rahul","Kiran"],

    "Age": [20,21,22,20,23],

    "Course": ["DS","ML","AI","DS","ML"],

    "Marks": [85,72,91,67,88],

    "City": ["Vijayawada","Hyderabad","Chennai","Vijayawada","Delhi"]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Student_ID   Name  Age Course  Marks        City
# 0           1    Anu   20     DS     85  Vijayawada
# 1           2   Ravi   21     ML     72   Hyderabad
# 2           3   Sita   22     AI     91     Chennai
# 3           4  Rahul   20     DS     67  Vijayawada
# 4           5  Kiran   23     ML     88       Delhi

# %%
print(df["Name"])
# Out:
# 0      Anu
# 1     Ravi
# 2     Sita
# 3    Rahul
# 4    Kiran
# Name: Name, dtype: object
